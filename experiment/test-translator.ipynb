# %% [markdown]
# ### Run in Google Colab

# %%
# %%capture
# !pip install fasttext
# !pip install emoji
# !pip install translators --upgrade

# %%
from google.colab import drive
import os

drive.mount('/content/drive')
os.chdir("/content/drive/MyDrive/Healthcare/")
# Out:
# Mounted at /content/drive

# %% [markdown]
# ### Import Library and Helper Functions

# %%
import os
import csv
import time
import json
import emoji
import fasttext
import numpy as np
import pandas as pd
import string
# import mlflow
import json
import pickle

from datetime import date
import translators as ts

from sklearn.model_selection import train_test_split
from sklearn.metrics import (f1_score,
                             precision_score,
                             recall_score, 
                             accuracy_score)
# Out:
# Using Indonesia server backend.

# %%
def remove_newline(sentence: str) -> str:
    """Remove newline."""
    sentence = sentence.replace("\n", "")
    sentence = " ".join(sentence.split())
    return sentence

def remove_underscore(sentence: str) -> str:
    """Remove underscore."""
    sentence = sentence.replace("_", " ")
    sentence = " ".join(sentence.split())
    return sentence

def remove_punctuation(sentence: str) -> str:
    """Remove punctuation from text."""
    sentence = sentence.translate(str.maketrans("", "", string.punctuation)).lower()
    sentence = " ".join(sentence.split())
    return sentence


def clean_nonASCII(sentence: str) -> str:
    """Remove emoji and ascii."""
    clean_sentence = emoji.get_emoji_regexp().sub(u" ", sentence)
    clean_sentence = clean_sentence.encode("ascii", "ignore").decode()
    clean_sentence = [
        x.strip().lower() for x in clean_sentence.split() if x.strip()
    ]
    return " ".join(clean_sentence)

#multiprocessing
from multiprocessing import  Pool
from functools import partial
from os import cpu_count
 
n_cpu = cpu_count()
 
def parallelize(data, func, num_of_processes=n_cpu):
    data_split = np.array_split(data, num_of_processes)
    pool = Pool(num_of_processes)
    data = pd.concat(pool.map(func, data_split))
    pool.close()
    pool.join()
    return data
 
def run_on_subset(func, data_subset):
    return data_subset.progress_apply(func)
 
def parallelize_on_rows(data, func, num_of_processes=n_cpu):
    return parallelize(data, partial(run_on_subset, func), num_of_processes)

def process_slug(subs):
    res = subs.lower()
    res = res.replace(' ','-')
    res = res.replace('(','')
    res = res.replace(')','')
    res = res.replace('≥','gte')
    res = res.replace('>','gt')
    res = res.replace('≤','lte')
    res = res.replace('<','lt')
    res = res.replace('/','atau')
    res = res.replace('&','dan')
    res = res.replace(',','')
    res = res.replace('.','')
    
    return res   

def lower(subs):
    res = subs.lower()
    return res

# %% [markdown]
# ### Explore Dataset

# %%
import pandas as pd

disease_df = pd.read_csv('dataset/disease.csv')
symptom_df = pd.read_csv('dataset/symptom.csv')

# %%
# translate symtom (gejala) ke bahasa a indonesia
# lambda x:model.predict(x,k=1)[0][0].replace("__label__","")
symptom_df['Clean Symptom (ID)'] = symptom_df['Clean Symptom'].apply(lambda x:ts.google(x,to_language='id'))

# %%
symptom_df
# Out:
#                   Symptom  weight         Clean Symptom  \
# 0                 itching       1               itching
# 1               skin_rash       3             skin rash
# 2    nodal_skin_eruptions       4  nodal skin eruptions
# 3     continuous_sneezing       4   continuous sneezing
# 4               shivering       5             shivering
# ..                    ...     ...                   ...
# 128    inflammatory_nails       2    inflammatory nails
# 129               blister       4               blister
# 130  red_sore_around_nose       2  red sore around nose
# 131     yellow_crust_ooze       3     yellow crust ooze
# 132             prognosis       5             prognosis
#
#                 Clean Symptom (ID)
# 0                            gatal
# 1                       ruam kulit
# 2              letusan kulit nodal
# 3             bersin terus menerus
# 4                        gemetaran
# ..                             ...
# 128                    Kuku radang
# 129                          lepuh
# 130  sakit merah di sekitar hidung
# 131                  Kapten kuning
# 132                       prognosa
#
# [133 rows x 4 columns]

# %%
# mengganti nilai NaN menjadi string " "
disease_df.fillna(" ", inplace=True)

# %%
disease_df
# Out:
#                                     Disease  \
# 0                             Drug Reaction
# 1                                   Malaria
# 2                                   Allergy
# 3                            Hypothyroidism
# 4                                 Psoriasis
# 5                                      GERD
# 6                       Chronic cholestasis
# 7                               hepatitis A
# 8                           Osteoarthristis
# 9   (vertigo) Paroymsal  Positional Vertigo
# 10                             Hypoglycemia
# 11                                     Acne
# 12                                 Impetigo
# 13                      Peptic ulcer diseae
# 14                              Common Cold
# 15                              Chicken pox
# 16                     Cervical spondylosis
# 17                          Hyperthyroidism
# 18                  Urinary tract infection
# 19                           Varicose veins
# 20                                     AIDS
# 21             Paralysis (brain hemorrhage)
# 22                                  Typhoid
# 23                              Hepatitis B
# 24                         Fungal infection
# 25                              Hepatitis C
# 26                                 Migraine
# 27                         Bronchial Asthma
# 28                      Alcoholic hepatitis
# 29                                 Jaundice
# 30                              Hepatitis E
# 31                                   Dengue
# 32                              Hepatitis D
# 33                             Heart attack
# 34                                Pneumonia
# 35                                Arthritis
# 36                          Gastroenteritis
# 37                             Tuberculosis
#
#                                           Description  \
# 0   An adverse drug reaction (ADR) is an injury ca...
# 1   An infectious disease caused by protozoan para...
# 2   An allergy is an immune system response to a f...
# 3   Hypothyroidism, also called underactive thyroi...
# 4   Psoriasis is a common skin disorder that forms...
# 5   Gastroesophageal reflux disease, or GERD, is a...
# 6   Chronic cholestatic diseases, whether occurrin...
# 7   Hepatitis A is a highly contagious liver infec...
# 8   Osteoarthritis is the most common form of arth...
# 9   Benign paroxysmal positional vertigo (BPPV) is...
# 10   Hypoglycemia is a condition in which your blo...
# 11  Acne vulgaris is the formation of comedones, p...
# 12  Impetigo (im-puh-TIE-go) is a common and highl...
# 13  Peptic ulcer disease (PUD) is a break in the i...
# 14  The common cold is a viral infection of your n...
# 15  Chickenpox is a highly contagious disease caus...
# 16  Cervical spondylosis is a general term for age...
# 17  Hyperthyroidism (overactive thyroid) occurs wh...
# 18  Urinary tract infection: An infection of the k...
# 19  A vein that has enlarged and twisted, often ap...
# 20  Acquired immunodeficiency syndrome (AIDS) is a...
# 21  Intracerebral hemorrhage (ICH) is when blood s...
# 22  An acute illness characterized by fever caused...
# 23  Hepatitis B is an infection of your liver. It ...
# 24  In humans, fungal infections occur when an inv...
# 25  Inflammation of the liver due to the hepatitis...
# 26  A migraine can cause severe throbbing pain or ...
# 27  Bronchial asthma is a medical condition which ...
# 28  Alcoholic hepatitis is a diseased, inflammator...
# 29  Yellow staining of the skin and sclerae (the w...
# 30  A rare form of liver inflammation caused by in...
# 31  an acute infectious disease caused by a flaviv...
# 32  Hepatitis D, also known as the hepatitis delta...
# 33  The death of heart muscle due to the loss of b...
# 34  Pneumonia is an infection in one or both lungs...
# 35  Arthritis is the swelling and tenderness of on...
# 36  Gastroenteritis is an inflammation of the dige...
# 37  Tuberculosis (TB) is an infectious disease usu...
#
#                              Disease Slug  \
# 0                           drug-reaction
# 1                                 malaria
# 2                                 allergy
# 3                          hypothyroidism
# 4                               psoriasis
# 5                                    gerd
# 6                     chronic-cholestasis
# 7                             hepatitis-a
# 8                         osteoarthristis
# 9   vertigo-paroymsal--positional-vertigo
# 10                           hypoglycemia
# 11                                   acne
# 12                               impetigo
# 13                    peptic-ulcer-diseae
# 14                            common-cold
# 15                            chicken-pox
# 16                   cervical-spondylosis
# 17                        hyperthyroidism
# 18                urinary-tract-infection
# 19                         varicose-veins
# 20                                   aids
# 21             paralysis-brain-hemorrhage
# 22                                typhoid
# 23                            hepatitis-b
# 24                       fungal-infection
# 25                            hepatitis-c
# 26                               migraine
# 27                       bronchial-asthma
# 28                    alcoholic-hepatitis
# 29                               jaundice
# 30                            hepatitis-e
# 31                                 dengue
# 32                            hepatitis-d
# 33                           heart-attack
# 34                              pneumonia
# 35                              arthritis
# 36                        gastroenteritis
# 37                           tuberculosis
#
#                             Precaution_1                        Precaution_2  \
# 0                        stop irritation            consult nearest hospital
# 1               Consult nearest hospital                     avoid oily food
# 2                         apply calamine             cover area with bandage
# 3                          reduce stress                            exercise
# 4       wash hands with warm soapy water        stop bleeding using pressure
# 5                 avoid fatty spicy food       avoid lying down after eating
# 6                             cold baths                  anti itch medicine
# 7               Consult nearest hospital                  wash hands through
# 8                          acetaminophen            consult nearest hospital
# 9                               lie down         avoid sudden change in body
# 10                      lie down on side                      check in pulse
# 11                            bath twice              avoid fatty spicy food
# 12      soak affected area in warm water                     use antibiotics
# 13                avoid fatty spicy food              consume probiotic food
# 14           drink vitamin c rich drinks                         take vapour
# 15                  use neem in bathing                  consume neem leaves
# 16          use heating pad or cold pack                            exercise
# 17                           eat healthy                             massage
# 18                 drink plenty of water           increase vitamin c intake
# 19  lie down flat and raise the leg high                        use oinments
# 20                       avoid open cuts                wear ppe if possible
# 21                               massage                         eat healthy
# 22           eat high calorie vegitables                  antiboitic therapy
# 23              consult nearest hospital                         vaccination
# 24                            bath twice  use detol or neem in bathing water
# 25              Consult nearest hospital                         vaccination
# 26                            meditation                       reduce stress
# 27             switch to loose cloothing                   take deep breaths
# 28              stop alcohol consumption                      consult doctor
# 29                 drink plenty of water                consume milk thistle
# 30              stop alcohol consumption                                rest
# 31               drink papaya leaf juice              avoid fatty spicy food
# 32                        consult doctor                          medication
# 33                        call ambulance              chew or swallow asprin
# 34                        consult doctor                          medication
# 35                              exercise            use hot and cold therapy
# 36      stop eating solid food for while      try taking small sips of water
# 37                           cover mouth                      consult doctor
#
#                               Precaution_3                       Precaution_4
# 0                         stop taking drug                          follow up
# 1                       avoid non veg food                 keep mosquitos out
# 2                                                 use ice to compress itching
# 3                              eat healthy                   get proper sleep
# 4                           consult doctor                         salt baths
# 5                  maintain healthy weight                           exercise
# 6                           consult doctor                        eat healthy
# 7                   avoid fatty spicy food                         medication
# 8                                follow up                         salt baths
# 9                avoid abrupt head movment                              relax
# 10                     drink sugary drinks                     consult doctor
# 11                   drink plenty of water            avoid too many products
# 12  remove scabs with wet compressed cloth                     consult doctor
# 13                          eliminate milk                      limit alcohol
# 14                         avoid cold food                keep fever in check
# 15                            take vaccine                avoid public places
# 16                   take otc pain reliver                     consult doctor
# 17                          use lemon balm  take radioactive iodine treatment
# 18                   drink cranberry juice                    take probiotics
# 19                    use vein compression          dont stand still for long
# 20                          consult doctor                          follow up
# 21                                exercise                     consult doctor
# 22                          consult doctor                         medication
# 23                             eat healthy                         medication
# 24                  keep infected area dry                   use clean cloths
# 25                             eat healthy                         medication
# 26             use poloroid glasses in sun                     consult doctor
# 27                   get away from trigger                          seek help
# 28                              medication                          follow up
# 29       eat fruits and high fiberous food                         medication
# 30                          consult doctor                         medication
# 31                     keep mosquitos away                      keep hydrated
# 32                             eat healthy                          follow up
# 33                               keep calm
# 34                                    rest                          follow up
# 35                         try acupuncture                            massage
# 36                                    rest              ease back into eating
# 37                              medication                               rest

# %%
# translate deskripsi, disease (penyakit), dan semua precaution ke bahasa indonesia
disease_df['Description (ID)'] = disease_df['Description'].apply(lambda x:ts.google(x,to_language='id'))
disease_df['Disease (ID)'] = disease_df['Disease'].apply(lambda x:ts.google(x,to_language='id'))
disease_df['Precaution_1 (ID)'] = disease_df['Precaution_1'].apply(lambda x:ts.google(x,to_language='id'))
disease_df['Precaution_2 (ID)'] = disease_df['Precaution_2'].apply(lambda x:ts.google(x,to_language='id'))
disease_df['Precaution_3 (ID)'] = disease_df['Precaution_3'].apply(lambda x:ts.google(x,to_language='id'))
disease_df['Precaution_4 (ID)'] = disease_df['Precaution_4'].apply(lambda x:ts.google(x,to_language='id'))

# %%
disease_df.head()
# Out:
#           Disease                                        Description  \
# 0   Drug Reaction  An adverse drug reaction (ADR) is an injury ca...
# 1         Malaria  An infectious disease caused by protozoan para...
# 2         Allergy  An allergy is an immune system response to a f...
# 3  Hypothyroidism  Hypothyroidism, also called underactive thyroi...
# 4       Psoriasis  Psoriasis is a common skin disorder that forms...
#
#      Disease Slug                      Precaution_1  \
# 0   drug-reaction                   stop irritation
# 1         malaria          Consult nearest hospital
# 2         allergy                    apply calamine
# 3  hypothyroidism                     reduce stress
# 4       psoriasis  wash hands with warm soapy water
#
#                    Precaution_2        Precaution_3  \
# 0      consult nearest hospital    stop taking drug
# 1               avoid oily food  avoid non veg food
# 2       cover area with bandage
# 3                      exercise         eat healthy
# 4  stop bleeding using pressure      consult doctor
#
#                   Precaution_4  \
# 0                    follow up
# 1           keep mosquitos out
# 2  use ice to compress itching
# 3             get proper sleep
# 4                   salt baths
#
#                                     Description (ID)    Disease (ID)  \
# 0  Reaksi obat yang merugikan (ADR) adalah cedera...     Reaksi obat
# 1  Penyakit menular yang disebabkan oleh parasit ...         Malaria
# 2  Alergi adalah respons sistem kekebalan tubuh t...          Alergi
# 3  Hipotiroidisme, juga disebut tiroid yang kuran...  Hipotiroidisme
# 4  Psoriasis adalah kelainan kulit umum yang memb...       Psoriasis
#
#                            Precaution_1 (ID)  \
# 0                           Hentikan iritasi
# 1  Konsultasikan dengan rumah sakit terdekat
# 2                          Terapkan Calamine
# 3                           mengurangi stres
# 4        Cuci tangan dengan air sabun hangat
#
#                            Precaution_2 (ID)            Precaution_3 (ID)  \
# 0  Konsultasikan dengan rumah sakit terdekat          berhenti minum obat
# 1                  Hindari makanan berminyak    Hindari Makanan Non Veget
# 2                 Area penutup dengan perban
# 3                                    latihan             makan yang sehat
# 4    Hentikan Pendarahan Menggunakan Tekanan  Konsultasikan dengan dokter
#
#                    Precaution_4 (ID)
# 0                    menindaklanjuti
# 1                     Jauhkan nyamuk
# 2  Gunakan es untuk mengompres gatal
# 3                      tidur nyenyak
# 4                        mandi garam

# %%
symptom_df.to_csv('dataset/symptom_id.csv',index=False)
disease_df.to_csv('dataset/disease_id.csv',index=False)
